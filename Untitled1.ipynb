# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('laptop.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
# 1             1         1.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                 Memory                           Gpu  ...     LG Lenovo  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  ...  False  False
# 1  128GB Flash Storage        Intel HD Graphics 6000  ...  False  False
#
#      MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba   Vero  Xiaomi
# 0  False     False      False  False    False    False  False   False
# 1  False     False      False  False    False    False  False   False
#
# [2 rows x 32 columns]

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 0',], inplace=True)

# %%
df.drop(columns=['Unnamed: 0.1'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1         0
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# Acer                 0
# Apple                0
# Asus                 0
# Chuwi                0
# Dell                 0
# Fujitsu              0
# Google               0
# HP                   0
# Huawei               0
# LG                   0
# Lenovo               0
# MSI                  0
# Mediacom             0
# Microsoft            0
# Razer                0
# Samsung              0
# Toshiba              0
# Vero                 0
# Xiaomi               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1        0
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Acer                0
# Apple               0
# Asus                0
# Chuwi               0
# Dell                0
# Fujitsu             0
# Google              0
# HP                  0
# Huawei              0
# LG                  0
# Lenovo              0
# MSI                 0
# Mediacom            0
# Microsoft           0
# Razer               0
# Samsung             0
# Toshiba             0
# Vero                0
# Xiaomi              0
# dtype: int64

# %%
df=df.join(pd.get_dummies(df['Company']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-401ea2636ba0> in <cell line: 1>()
# ----> 1 df=df.join(pd.get_dummies(df['Company']))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10410                     validate=validate,
#   10411                 )
# > 10412             return merge(
#   10413                 self,
#   10414                 other,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     181             validate=validate,
#     182         )
# --> 183         return op.get_result(copy=copy)
#     184
#     185
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     883         join_index, left_indexer, right_indexer = self._get_join_info()
#     884
# --> 885         result = self._reindex_and_concat(
#     886             join_index, left_indexer, right_indexer, copy=copy
#     887         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     835         right = self.right[:]
#     836
# --> 837         llabels, rlabels = _items_overlap_with_suffix(
#     838             self.left._info_axis, self.right._info_axis, self.suffixes
#     839         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2659
#    2660     if not lsuffix and not rsuffix:
# -> 2661         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2662
#    2663     def renamer(x, suffix: str | None):
#
# ValueError: columns overlap but no suffix specified: Index(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google', 'HP',
#        'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft', 'Razer',
#        'Samsung', 'Toshiba', 'Vero', 'Xiaomi'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
# 1             1         1.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                 Memory                           Gpu  ...     LG Lenovo  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  ...  False  False
# 1  128GB Flash Storage        Intel HD Graphics 6000  ...  False  False
#
#      MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba   Vero  Xiaomi
# 0  False     False      False  False    False    False  False   False
# 1  False     False      False  False    False    False  False   False
#
# [2 rows x 32 columns]

# %%
df=df.join(pd.get_dummies(df.TypeName))

# %%
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Company   TypeName Inches  \
# 0             0         0.0   Apple  Ultrabook   13.3
# 1             1         1.0   Apple  Ultrabook   13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                 Memory                           Gpu  ... Samsung Toshiba  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  ...   False   False
# 1  128GB Flash Storage        Intel HD Graphics 6000  ...   False   False
#
#     Vero  Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0  False   False               False   False    False     False       True
# 1  False   False               False   False    False     False       True
#
#    Workstation
# 0        False
# 1        False
#
# [2 rows x 38 columns]

# %%
df['ScreenResolution'] = df['ScreenResolution'].astype(str).str.split(" ").apply(lambda x: x[-1])

# %%
df['Screen Width']= df['ScreenResolution'].str.split("x").apply(lambda x: x[0])
df['Screen Height']= df['ScreenResolution'].str.split("x").apply(lambda x: x[1])

# %%
df.head(2)
# Out:
#   Company   TypeName Inches ScreenResolution                   Cpu  Ram  \
# 0   Apple  Ultrabook   13.3        2560x1600  Intel Core i5 2.3GHz  8GB
# 1   Apple  Ultrabook   13.3         1440x900  Intel Core i5 1.8GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  ...  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  ...
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg  ...
#
#     Vero  Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0  False   False               False   False    False     False       True
# 1  False   False               False   False    False     False       True
#
#    Workstation  Screen Width  Screen Height
# 0        False          2560           1600
# 1        False          1440            900
#
# [2 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company             1273 non-null   object
#  1   TypeName            1273 non-null   object
#  2   Inches              1273 non-null   object
#  3   ScreenResolution    1273 non-null   object
#  4   Cpu                 1273 non-null   object
#  5   Ram                 1273 non-null   object
#  6   Memory              1273 non-null   object
#  7   Gpu                 1273 non-null   object
#  8   OpSys               1273 non-null   object
#  9   Weight              1273 non-null   object
#  10  Price               1273 non-null   float64
#  11  Acer                1273 non-null   bool
#  12  Apple               1273 non-null   bool
#  13  Asus                1273 non-null   bool
#  14  Chuwi               1273 non-null   bool
#  15  Dell                1273 non-null   bool
#  16  Fujitsu             1273 non-null   bool
#  17  Google              1273 non-null   bool
#  18  HP                  1273 non-null   bool
#  19  Huawei              1273 non-null   bool
#  20  LG                  1273 non-null   bool
#  21  Lenovo              1273 non-null   bool
#  22  MSI                 1273 non-null   bool
#  23  Mediacom            1273 non-null   bool
#  24  Microsoft           1273 non-null   bool
#  25  Razer               1273 non-null   bool
#  26  Samsung             1273 non-null   bool
#  27  Toshiba             1273 non-null   bool
#  28  Vero                1273 non-null   bool
#  29  Xiaomi              1273 non-null   bool
#  30  2 in 1 Convertible  1273 non-null   bool
#  31  Gaming              1273 non-null   bool
#  32  Netbook             1273 non-null   bool
#  33  Notebook            1273 non-null   bool
#  34  Ultrabook           1273 non-null   bool
#  35  Workstation         1273 non-null   bool
#  36  Screen Width        1273 non-null   object
#  37  Screen Height       1273 non-null   object
# dtypes: bool(25), float64(1), object(12)
# memory usage: 202.6+ KB

# %%
df['Cpu_Brand'] = df['Cpu'].str.split(" ").apply(lambda x: x[0])
df['Cpu_Frequency'] = df['Cpu'].str.split(" ").apply(lambda x: x[-1])

# %%
df.columns
# Out:
# Index(['Inches', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'Acer',
#        'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google', 'HP', 'Huawei',
#        'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft', 'Razer', 'Samsung',
#        'Toshiba', 'Vero', 'Xiaomi', '2 in 1 Convertible', 'Gaming', 'Netbook',
#        'Notebook', 'Ultrabook', 'Workstation', 'Screen Width', 'Screen Height',
#        'Cpu_Brand', 'Cpu_Frequency'],
#       dtype='object')

# %%
df.drop(columns=['Cpu','ScreenResolution','TypeName','Cpu'], inplace=True)
df.drop(columns=['Company'], inplace=True)

# %%
df['Acer'] = df['Acer'].astype(int)
df['Apple'] = df['Apple'].astype(int)
df['Asus'] = df['Asus'].astype(int)
df['Dell'] = df['Dell'].astype(int)
df['Chuwi'] = df['Chuwi'].astype(int)
df['Lenovo'] = df['Lenovo'].astype(int)
df['MSI'] = df['MSI'].astype(int)
df['Razer'] = df['Razer'].astype(int)
df['Fujitsu'] = df['Fujitsu'].astype(int)
df['Microsoft'] = df['Microsoft'].astype(int)
df['Toshiba'] = df['Toshiba'].astype(int)
df['Huawei'] = df['Huawei'].astype(int)
df['Samsung'] = df['Samsung'].astype(int)
df['Mediacom'] = df['Mediacom'].astype(int)
df['Xiaomi'] = df['Xiaomi'].astype(int)
df['LG']= df['LG'].astype(int)
df['Google']= df['Google'].astype(int)
df['Vero'] = df['Vero'].astype(int)
df['HP'] = df['HP'].astype(int)

# %%
df['2 in 1 Convertible'] =df['2 in 1 Convertible'].astype(int)
df['Gaming'] = df['Gaming'].astype(int)
df['Netbook'] = df['Netbook'].astype(int)
df['Ultrabook'] = df['Ultrabook'].astype(int)
df['Notebook'] = df['Notebook'].astype(int)
df['Workstation'] = df['Workstation'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Inches              1273 non-null   object
#  1   Ram                 1273 non-null   object
#  2   Memory              1273 non-null   object
#  3   Gpu                 1273 non-null   object
#  4   OpSys               1273 non-null   object
#  5   Weight              1273 non-null   object
#  6   Price               1273 non-null   float64
#  7   Acer                1273 non-null   int64
#  8   Apple               1273 non-null   int64
#  9   Asus                1273 non-null   int64
#  10  Chuwi               1273 non-null   int64
#  11  Dell                1273 non-null   int64
#  12  Fujitsu             1273 non-null   int64
#  13  Google              1273 non-null   int64
#  14  HP                  1273 non-null   int64
#  15  Huawei              1273 non-null   int64
#  16  LG                  1273 non-null   int64
#  17  Lenovo              1273 non-null   int64
#  18  MSI                 1273 non-null   int64
#  19  Mediacom            1273 non-null   int64
#  20  Microsoft           1273 non-null   int64
#  21  Razer               1273 non-null   int64
#  22  Samsung             1273 non-null   int64
#  23  Toshiba             1273 non-null   int64
#  24  Vero                1273 non-null   int64
#  25  Xiaomi              1273 non-null   int64
#  26  2 in 1 Convertible  1273 non-null   int64
#  27  Gaming              1273 non-null   int64
#  28  Netbook             1273 non-null   int64
#  29  Notebook            1273 non-null   int64
#  30  Ultrabook           1273 non-null   int64
#  31  Workstation         1273 non-null   int64
#  32  Screen Width        1273 non-null   object
#  33  Screen Height       1273 non-null   object
#  34  Cpu_Brand           1273 non-null   object
#  35  Cpu_Frequency       1273 non-null   object
# dtypes: float64(1), int64(25), object(10)
# memory usage: 400.3+ KB

# %%
df['Cpu_Frequency']
# Out:
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 1298    []
# 1299    []
# 1300    []
# 1301    []
# 1302    []
# Name: Cpu_Frequency, Length: 1273, dtype: object

# %%
df.head(2)
# Out:
#   Inches  Ram               Memory                           Gpu  OpSys  \
# 0   13.3  8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 1   13.3  8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
#
#    Weight       Price  Acer  Apple  Asus  ...  2 in 1 Convertible  Gaming  \
# 0  1.37kg  71378.6832     0      1     0  ...                   0       0
# 1  1.34kg  47895.5232     0      1     0  ...                   0       0
#
#    Netbook  Notebook  Ultrabook  Workstation  Screen Width  Screen Height  \
# 0        0         0          1            0          2560           1600
# 1        0         0          1            0          1440            900
#
#    Cpu_Brand  Cpu_Frequency
# 0      Intel             []
# 1      Intel             []
#
# [2 rows x 36 columns]
